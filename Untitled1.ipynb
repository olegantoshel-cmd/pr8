# %%
import re
INN_PATTERN = r'^\d{12}$'

def validate_inn():
    while True:
        inn = input("Введите ваш ИНН (12 цифр): ").strip()

        if re.fullmatch(INN_PATTERN, inn):
            print(f" ИНН принят: {inn}")
            return inn
        else:
            print(" Неверный формат ИНН. ИНН должен состоять ровно из 12 цифр.")


user_inn = validate_inn()
print(f"Ввод завершен. ИНН: {user_inn}")

print("\n" + "="*50 + "\n")
# Out:
# Введите ваш ИНН (12 цифр): 123123123
#  Неверный формат ИНН. ИНН должен состоять ровно из 12 цифр.
# Введите ваш ИНН (12 цифр): 123123123123
#  ИНН принят: 123123123123
# Ввод завершен. ИНН: 123123123123
#
# ...
